# %% [markdown]
# # Extraindo tabela dos pdfs de Materiais de uso geral e informática

# %% [markdown]
# ### Esse notebook tem o objetivo de:
#     - [ ] Extrair a tabela nos pdfs
#     - [ ] Padronizar o formato
#     - [ ] Fatorar uma função que automatiza isso

# %% [markdown]
# ### Prerequisitos:
#     - [X] Baixar pelo menos um PDF para referencia

# %%
PDF = '../data/pdfs/materiais-de-uso-geral-e-informatica/materiaisdiversos.pdf'

# %%
import sys
sys.path.insert(0, '..')
from IPython.display import HTML

def show_pdf(path, page=0, height=400):
    return HTML(f'''
        <iframe
            src="{path}#page={page}"
            width=100%
            height={height}
            >
        </iframe>
    ''')

# %%
show_pdf(PDF)
# Out:
#         <iframe
#             src="../data/pdfs/materiais-de-uso-geral-e-informatica/materiaisdiversos.pdf#page=0"
#             width=100%
#             height=400
#             >
#         </iframe>

# %%
from lib.materiais_de_uso_geral_e_informatica import (
    extract_table,
    format_table,
    extrair_df,
)
from tabula import read_pdf

# %%
pandas_options = {
    'dtype': str,
}

df = read_pdf(
    PDF,
    spreadsheet=True,
    pandas_options=pandas_options,
    pages='all',
)

df.head()
# Out:
#   N°          CÓDIGO                                 Materiais Diversos Unid  \
# 0  1  8540.00.019-76  ABSORVENTE HIGIÊNICO PÓS-PARTO, HIPOALERGÊNICO...   UN
# 1  2  7930.00.026-66  ÁGUA SANITÁRIA, LÍQUIDO HOMOGÊNEO, GERMICIDA, ...   UN
# 2  3  6810.10.500-37  ALCOOL,  GEL  FRASCO  (REFIL)  C/ MIN. 800ML M...   UN
# 3  4  6810.10.395-72  ÁLCOOL ETÍLICO, A 70o, DE USO HOSPITALAR PARA ...   UN
# 4  5  6810.10.118-05  ÁLCOOL ETÍLICO ANIDRO (ABSOLUTO), FILTRADO, 99...   UN
#
#   R$ Preço
# 0     0,48
# 1     1,63
# 2    12,10
# 3     4,28
# 4     6,31

# %%
no = df.columns[0]
df[df[no] == no]
# Out:
#      N°  CÓDIGO  Materiais Diversos  Unid  R$ Preço
# 13   N°  CÓDIGO  Materiais Diversos  Unid  R$ Preço
# 25   N°  CÓDIGO  Materiais Diversos  Unid  R$ Preço
# 39   N°  CÓDIGO  Materiais Diversos  Unid  R$ Preço
# 54   N°  CÓDIGO  Materiais Diversos  Unid  R$ Preço
# 68   N°  CÓDIGO  Materiais Diversos  Unid  R$ Preço
# 81   N°  CÓDIGO  Materiais Diversos  Unid  R$ Preço
# 99   N°  CÓDIGO  Materiais Diversos  Unid  R$ Preço
# 121  N°  CÓDIGO  Materiais Diversos  Unid  R$ Preço
# 136  N°  CÓDIGO  Materiais Diversos  Unid  R$ Preço
# 147  N°  CÓDIGO  Materiais Diversos  Unid  R$ Preço
# 156  N°  CÓDIGO  Materiais Diversos  Unid  R$ Preço
# 165  N°  CÓDIGO  Materiais Diversos  Unid  R$ Preço
# 181  N°  CÓDIGO  Materiais Diversos  Unid  R$ Preço

# %%
df[df['CÓDIGO'].isnull()].index
# Out:
# Int64Index([152, 153, 154, 155], dtype='int64')

# %%
from typing import Iterable, Iterator, Tuple, Any
from itertools import takewhile, count, tee

def pairwise(it : Iterable[Any]) -> Iterator[Tuple[Any, Any]]:
    "s -> (s0,s1), (s1,s2), (s2, s3), ..."
    a, b = tee(it)
    next(b, None)
    return zip(a, b)

# %%
def take_consecutive(it):
    it = iter(it)
    it = pairwise(it)
    it = takewhile(lambda t: t[0] + 1 == t[1], it)
    it = list(it)
    it = [a for a, b in it] + [it[-1][1]]
    return it

# %%
take_consecutive(df[df['CÓDIGO'].isnull()].index)
# Out:
# [152, 153, 154, 155]

# %%
import pandas as pd
from lib.typing import Path
from lib.util import drop_repeated_headers

def extract_table(path: Path) -> pd.DataFrame:
    pandas_options = {
        'dtype': str,
    }
    
    return read_pdf(
        path,
        spreadsheet=True,
        pandas_options=pandas_options,
        pages='all',
    )


def format_table(df: pd.DataFrame,
                ) -> Tuple[pd.DataFrame,
                           pd.DataFrame]:
    df = drop_repeated_headers(df)
    start, *_, stop = take_consecutive(df[df['CÓDIGO'].isnull()].index)
    return df.iloc[:start], df.iloc[stop+1:].reset_index(drop=True)

# %%
df = extract_table(PDF)
df.head()
# Out:
#   N°          CÓDIGO                                 Materiais Diversos Unid  \
# 0  1  8540.00.019-76  ABSORVENTE HIGIÊNICO PÓS-PARTO, HIPOALERGÊNICO...   UN
# 1  2  7930.00.026-66  ÁGUA SANITÁRIA, LÍQUIDO HOMOGÊNEO, GERMICIDA, ...   UN
# 2  3  6810.10.500-37  ALCOOL,  GEL  FRASCO  (REFIL)  C/ MIN. 800ML M...   UN
# 3  4  6810.10.395-72  ÁLCOOL ETÍLICO, A 70o, DE USO HOSPITALAR PARA ...   UN
# 4  5  6810.10.118-05  ÁLCOOL ETÍLICO ANIDRO (ABSOLUTO), FILTRADO, 99...   UN
#
#   R$ Preço
# 0     0,48
# 1     1,63
# 2    12,10
# 3     4,28
# 4     6,31

# %%
a, b = format_table(df)

# %%
a.head()
# Out:
#   N°          CÓDIGO                                 Materiais Diversos Unid  \
# 0  1  8540.00.019-76  ABSORVENTE HIGIÊNICO PÓS-PARTO, HIPOALERGÊNICO...   UN
# 1  2  7930.00.026-66  ÁGUA SANITÁRIA, LÍQUIDO HOMOGÊNEO, GERMICIDA, ...   UN
# 2  3  6810.10.500-37  ALCOOL,  GEL  FRASCO  (REFIL)  C/ MIN. 800ML M...   UN
# 3  4  6810.10.395-72  ÁLCOOL ETÍLICO, A 70o, DE USO HOSPITALAR PARA ...   UN
# 4  5  6810.10.118-05  ÁLCOOL ETÍLICO ANIDRO (ABSOLUTO), FILTRADO, 99...   UN
#
#   R$ Preço
# 0     0,48
# 1     1,63
# 2    12,10
# 3     4,28
# 4     6,31

# %%
b.head()
# Out:
#   N°          CÓDIGO                                 Materiais Diversos Unid  \
# 0  1  7445.02.116-85  CARTUCHO, TINTA, COLORIDA, PARA IMPRESSORA A J...   UN
# 1  2  7445.02.072-20  CARTUCHO, TINTA COLORIDA, PARA IMPRESSORA A JA...   UN
# 2  3  7445.02.010-27  CARTUCHO, TINTA COLORIDA, PARA IMPRESSORA A JA...   UN
# 3  4  7445.02.112-51  CARTUCHO, TINTA COLORIDA, PARA IMPRESSORA A JA...   UN
# 4  5  7445.02.080-30  CARTUCHO, TINTA, COLORIDA, PARA IMPRESSORA A J...   UN
#
#   R$ Preço
# 0   190,00
# 1   163,08
# 2    99,00
# 3   157,50
# 4   224,10

# %% [markdown]
# ### Tem um caso especial que precisa ser divido de forma dirente que os outros

# %%
SPECIAL_CASE = '../data/pdfs/materiais-de-uso-geral-e-informatica/catalogo_materiais_diversos.pdf'

# %%
show_pdf(SPECIAL_CASE, page=11, height=600)
# Out:
#         <iframe
#             src="../data/pdfs/materiais-de-uso-geral-e-informatica/catalogo_materiais_diversos.pdf#page=11"
#             width=100%
#             height=600
#             >
#         </iframe>

# %%
df = extract_table(SPECIAL_CASE)
df.head()
# Out:
#   N°          CÓDIGO                                 Materiais Diversos Unid  \
# 0  1  8540.00.019-76  ABSORVENTE HIGIÊNICO PÓS-PARTO, HIPOALERGÊNICO...   UN
# 1  2  7930.00.026-66  ÁGUA SANITÁRIA, LÍQUIDO HOMOGÊNEO, GERMICIDA, ...   UN
# 2  3  6810.10.500-37  ALCOOL,  GEL  FRASCO  (REFIL)  C/ MIN. 800ML M...   UN
# 3  4  6810.10.395-72  ÁLCOOL ETÍLICO, A 70o, DE USO HOSPITALAR PARA ...   UN
# 4  5  6810.10.118-05  ÁLCOOL ETÍLICO ANIDRO (ABSOLUTO), FILTRADO, 99...   UN
#
#   R$ Preço
# 0     0,48
# 1     1,56
# 2     8,30
# 3     6,25
# 4     5,99

# %%
df = drop_repeated_headers(df)
df.head()
# Out:
#   N°          CÓDIGO                                 Materiais Diversos Unid  \
# 0  1  8540.00.019-76  ABSORVENTE HIGIÊNICO PÓS-PARTO, HIPOALERGÊNICO...   UN
# 1  2  7930.00.026-66  ÁGUA SANITÁRIA, LÍQUIDO HOMOGÊNEO, GERMICIDA, ...   UN
# 2  3  6810.10.500-37  ALCOOL,  GEL  FRASCO  (REFIL)  C/ MIN. 800ML M...   UN
# 3  4  6810.10.395-72  ÁLCOOL ETÍLICO, A 70o, DE USO HOSPITALAR PARA ...   UN
# 4  5  6810.10.118-05  ÁLCOOL ETÍLICO ANIDRO (ABSOLUTO), FILTRADO, 99...   UN
#
#   R$ Preço
# 0     0,48
# 1     1,56
# 2     8,30
# 3     6,25
# 4     5,99

# %%
df[df[df.columns[0]] == '1'].index
# Out:
# Int64Index([0, 144], dtype='int64')

# %% [markdown]
# ### Mais um caso especial:

# %%
SPECIAL_CASE = '../data/pdfs/materiais-de-uso-geral-e-informatica/materiais_diversos_4_2016.pdf'

# %%
show_pdf(SPECIAL_CASE)
# Out:
#         <iframe
#             src="../data/pdfs/materiais-de-uso-geral-e-informatica/materiais_diversos_4_2016.pdf#page=0"
#             width=100%
#             height=400
#             >
#         </iframe>

# %%
df = extract_table(SPECIAL_CASE)
df.head()
# Out:
#    1  8540.00.019-76  \
# 0  2  7930.00.026-66
# 1  3  6810.10.500-37
# 2  4  6810.10.395-72
# 3  5  6810.10.118-05
# 4  6  6810.10.502-07
#
#   ABSORVENTE HIGIÊNICO PÓS-PARTO, HIPOALERGÊNICO,\r40X10X1CM, PARA USO PÓS-PARTO CONFECCIONADO COM\rMATERIAL ABSORVENTE, HIPOALERGÊNICO, COM GEL\rDISTRIBUÍDO DE FORMA A GARANTIR UMA BOA ABSORÇÃO DE\rFLUXO, COM COBERTURA INTERNA DE FALSO TECIDO, REVESTIDO\rEXTERNAMENTE POR PELÍCULA IMPERMEÁVEL, DIMENSÕES\rMÍNIMAS DA ÁREA ABSORVÍVEL 40XABSORVENTE HIGIÊNICO PÓS-\rPARTO, HIPOALERGÊNICO, 40X10X1CM, CONFECCIONADO COM\rMATERIAL ABSORVENTE 40X10X1CM, EMBALAGEM CONTENDO\rEXTERNAMENTE DADOS DE IDENTIFICAÇÃO E PROCEDÊNCIA,\rDATA DA FABRICAÇÃO E TEMPO DE VALIDADE  \
# 0  ÁGUA SANITÁRIA, LÍQUIDO HOMOGÊNEO, GERMICIDA, ...
# 1  ALCOOL,  GEL  FRASCO  (REFIL)  C/ MIN. 800ML M...
# 2  ÁLCOOL ETÍLICO, A 70o, DE USO HOSPITALAR PARA ...
# 3  ÁLCOOL ETÍLICO ANIDRO (ABSOLUTO), FILTRADO, 99...
# 4  ALCOOL ETILICO HIDRATADO, GEL, 65G. A 70G.INPM...
#
#    UN  0,48
# 0  UN  1,56
# 1  UN  8,30
# 2  UN  5,99
# 3  UN  5,99
# 4  UN  6,80

# %%
df[df[df.columns[0]] == '1']
# Out:
#      1  8540.00.019-76  \
# 143  1  7445.02.116-85
#
#     ABSORVENTE HIGIÊNICO PÓS-PARTO, HIPOALERGÊNICO,\r40X10X1CM, PARA USO PÓS-PARTO CONFECCIONADO COM\rMATERIAL ABSORVENTE, HIPOALERGÊNICO, COM GEL\rDISTRIBUÍDO DE FORMA A GARANTIR UMA BOA ABSORÇÃO DE\rFLUXO, COM COBERTURA INTERNA DE FALSO TECIDO, REVESTIDO\rEXTERNAMENTE POR PELÍCULA IMPERMEÁVEL, DIMENSÕES\rMÍNIMAS DA ÁREA ABSORVÍVEL 40XABSORVENTE HIGIÊNICO PÓS-\rPARTO, HIPOALERGÊNICO, 40X10X1CM, CONFECCIONADO COM\rMATERIAL ABSORVENTE 40X10X1CM, EMBALAGEM CONTENDO\rEXTERNAMENTE DADOS DE IDENTIFICAÇÃO E PROCEDÊNCIA,\rDATA DA FABRICAÇÃO E TEMPO DE VALIDADE  \
# 143  CARTUCHO, TINTA, COLORIDA, PARA IMPRESSORA A J...
#
#      UN    0,48
# 143  UN  155,57

# %%
def extract_table(path: Path) -> pd.DataFrame:
    pandas_options = {
        'dtype': str,
        'header': None,
        'names': ['N°',  'CÓDIGO', 'Materiais Diversos', 'Unid', 'R$ Preço'],
    }
    
    return read_pdf(
        path,
        spreadsheet=True,
        pandas_options=pandas_options,
        pages='all',
    )

# %%
df = extract_table(SPECIAL_CASE)
df.head()
# Out:
#   N°          CÓDIGO                                 Materiais Diversos Unid  \
# 0  1  8540.00.019-76  ABSORVENTE HIGIÊNICO PÓS-PARTO, HIPOALERGÊNICO...   UN
# 1  2  7930.00.026-66  ÁGUA SANITÁRIA, LÍQUIDO HOMOGÊNEO, GERMICIDA, ...   UN
# 2  3  6810.10.500-37  ALCOOL,  GEL  FRASCO  (REFIL)  C/ MIN. 800ML M...   UN
# 3  4  6810.10.395-72  ÁLCOOL ETÍLICO, A 70o, DE USO HOSPITALAR PARA ...   UN
# 4  5  6810.10.118-05  ÁLCOOL ETÍLICO ANIDRO (ABSOLUTO), FILTRADO, 99...   UN
#
#   R$ Preço
# 0     0,48
# 1     1,56
# 2     8,30
# 3     5,99
# 4     5,99

# %%
df[df[df.columns[0]] == '1']
# Out:
#     N°          CÓDIGO                                 Materiais Diversos  \
# 0    1  8540.00.019-76  ABSORVENTE HIGIÊNICO PÓS-PARTO, HIPOALERGÊNICO...
# 144  1  7445.02.116-85  CARTUCHO, TINTA, COLORIDA, PARA IMPRESSORA A J...
#
#     Unid R$ Preço
# 0     UN     0,48
# 144   UN   155,57

# %%
df = extract_table(PDF)
df = drop_repeated_headers(df)
df.head()
# Out:
#   N°          CÓDIGO                                 Materiais Diversos Unid  \
# 0  1  8540.00.019-76  ABSORVENTE HIGIÊNICO PÓS-PARTO, HIPOALERGÊNICO...   UN
# 1  2  7930.00.026-66  ÁGUA SANITÁRIA, LÍQUIDO HOMOGÊNEO, GERMICIDA, ...   UN
# 2  3  6810.10.500-37  ALCOOL,  GEL  FRASCO  (REFIL)  C/ MIN. 800ML M...   UN
# 3  4  6810.10.395-72  ÁLCOOL ETÍLICO, A 70o, DE USO HOSPITALAR PARA ...   UN
# 4  5  6810.10.118-05  ÁLCOOL ETÍLICO ANIDRO (ABSOLUTO), FILTRADO, 99...   UN
#
#   R$ Preço
# 0     0,48
# 1     1,63
# 2    12,10
# 3     4,28
# 4     6,31
